# %%
import pandas as pd
from typing import Dict, List
from itertools import starmap
import re

# %%
df = pd.read_csv("szczepionka_since_2020-12-01.csv")[["created_at", "date", "tweet"]]

# %%
import torch
from os.path import join, dirname, realpath
from transformers import XLMTokenizer, RobertaModel
from typing import List

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"


def merge(sequences: List[torch.tensor]):
    """
    Given the list of sequences embeddings where every seq has a different num of tokens the method converts
    the list into a tensor of size (N, L, 768) where N is the num of sequences in list and L is the longest sequence
    :param sequences: List of tensors of embeddings for tokens in sentences
    :return: tensor of size (N, L, 768)
    """
    lengths = [len(seq) for seq in sequences]
    vector_size = 768
    padded_seqs = torch.zeros(len(sequences), max(lengths), vector_size)
    for i, seq in enumerate(sequences):
        end = lengths[i]
        padded_seqs[i, (max(lengths) - end) :] = seq[:end]
    return padded_seqs


@torch.no_grad()
def get_embedding_for_list_of_texts(
    list_of_texts: List[str],
) -> (torch.tensor, torch.tensor):
    """
    For a given list of sentences the function return embedding generated by BERT
    :param text: Sentence for which u want to get an embedding
    :return: (tensor of embeddings for each token in sentneces, average embedding of a sentences)
    """
    tokenizer = XLMTokenizer.from_pretrained('allegro/herbert-klej-cased-tokenizer-v1')
    bert_model = RobertaModel.from_pretrained('allegro/herbert-klej-cased-v1').to(DEVICE)
    
    list_of_sentence_embeddings = []
    list_of_sequence_embeddings = []

    for text in list_of_texts:
        encoded_input = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
        outputs = bert_model(encoded_input)

        sequence_tokens_embedding = outputs[0].squeeze(dim=0)
        sentence_embedding = outputs[1].squeeze(dim=0)

        list_of_sequence_embeddings.append(sequence_tokens_embedding)
        list_of_sentence_embeddings.append(sentence_embedding)

    seq_embeddings_tensor = merge(list_of_sequence_embeddings)
    sentence_embeddings_tensor = torch.stack(list_of_sentence_embeddings, dim=0)

    return seq_embeddings_tensor, sentence_embeddings_tensor

# %%
def _replace_emotes_with_text(
        text: str,
        emote_to_text: Dict[str, str]
    ) -> str:
        for emote, emote_text in emote_to_text.items():
            text = text.replace(emote, emote_text)

        return text

def _remove_urls_from_text(text: str) -> str:
    text = re.sub(r'\S+://\S+', '', text, flags=re.MULTILINE)
    return text

# %%
from pathlib import Path
import json
import pickle
from pathlib import Path
import pandas as pd
from os.path import join


EMOTE_TO_TEXT_PATH = Path('../../data/emote_to_text.json')

with EMOTE_TO_TEXT_PATH.open(encoding='utf8') as file:
    emote_to_text = json.load(file)

# %%
texts = starmap(
            _replace_emotes_with_text,
            zip(df.tweet.tolist(), [emote_to_text] * len(df))
        )

texts = map(_remove_urls_from_text, texts)

texts = list(texts)



df["processed_tweets"] = texts

# %%
seq_embeddings_tensor, sentence_embeddings_tensor = get_embedding_for_list_of_texts(df.processed_tweets)

# %%
from seq_model import HerbertEmotionSequenceClassifier
from torch.nn import Softmax

# %%
classification_model = HerbertEmotionSequenceClassifier()

state_dict_path = "../wust_seq_model.pth"

classification_model.load_state_dict(torch.load(state_dict_path), strict=False)
classification_model = classification_model.eval().to(DEVICE)

softmax = Softmax(dim=1)

# %%
torch.cuda.empty_cache()

# %%
with torch.no_grad():
    predictions_1 = softmax(classification_model(seq_embeddings_tensor[:3000]).to(DEVICE)).cpu().numpy()
    predictions_2 = softmax(classification_model(seq_embeddings_tensor[3000:]).to(DEVICE)).cpu().numpy()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-c207cd19f44d> in <module>
#       1 with torch.no_grad():
# ----> 2     predictions_1 = softmax(classification_model(seq_embeddings_tensor[:3000]).to(DEVICE)).cpu().numpy()
#       3     predictions_2 = softmax(classification_model(seq_embeddings_tensor[3000:]).to(DEVICE)).cpu().numpy()
#
# /anaconda/envs/jupyterhub/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/project-polish-emotions-classifier/app/twitter_analysis/seq_model.py in forward(self, embedded_inputs)
#      54
#      55     def forward(self, embedded_inputs):
# ---> 56         o, h = self.rnn(embedded_inputs)
#      57         hidden_latent_vector=torch.cat([h[0],h[1]],dim=1)
#      58         hidden_latent_vector=h[0]
#
# /anaconda/envs/jupyterhub/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /anaconda/envs/jupyterhub/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     738         if batch_sizes is None:
#     739             result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 740                              self.dropout, self.training, self.bidirectional, self.batch_first)
#     741         else:
#     742             result = _VF.gru(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# RuntimeError: Input and parameter tensors are not at the same device, found input tensor at cpu and parameter tensor at cuda:0

# %%
import numpy as np

predictions = np.concatenate((predictions_1, predictions_2), axis=0)

# %%
predictions.shape
# Out:
# (6624, 9)

# %%
emotion_dict = {
    "oczekiwanie": 0,
    "podziw": 1,
    "radosc": 2,
    "smutek": 3,
    "strach": 4,
    "wstret": 5,
    "zaskoczenie": 6,
    "zlosc": 7,
    "neutralny": 8,
    "neutralne": 8,
}

# %%
emotion_list = {}

for emotion, column in emotion_dict.items():
    emotion_list[emotion] = predictions[:, column].tolist()

# %%
# emotion_list

# %%
for emotion in emotion_dict.keys():
    df[emotion] = emotion_list[emotion]

# %%
df
# Out:
#                    created_at        date  \
# 0     2021-01-21 17:14:32 CET  2021-01-21
# 1     2021-01-21 16:55:48 CET  2021-01-21
# 2     2021-01-21 16:22:05 CET  2021-01-21
# 3     2021-01-21 16:22:04 CET  2021-01-21
# 4     2021-01-21 16:22:02 CET  2021-01-21
# 5     2021-01-21 16:12:42 CET  2021-01-21
# 6     2021-01-21 16:09:07 CET  2021-01-21
# 7     2021-01-21 16:01:00 CET  2021-01-21
# 8     2021-01-21 15:43:33 CET  2021-01-21
# 9     2021-01-21 15:43:21 CET  2021-01-21
# 10    2021-01-21 15:13:40 CET  2021-01-21
# 11    2021-01-21 15:12:13 CET  2021-01-21
# 12    2021-01-21 14:54:50 CET  2021-01-21
# 13    2021-01-21 14:29:39 CET  2021-01-21
# 14    2021-01-21 14:29:26 CET  2021-01-21
# 15    2021-01-21 14:28:06 CET  2021-01-21
# 16    2021-01-21 14:25:16 CET  2021-01-21
# 17    2021-01-21 14:19:10 CET  2021-01-21
# 18    2021-01-21 13:11:31 CET  2021-01-21
# 19    2021-01-21 12:41:11 CET  2021-01-21
# 20    2021-01-21 12:21:07 CET  2021-01-21
# 21    2021-01-21 12:21:00 CET  2021-01-21
# 13    Punkt szczepień na MTP będzie mógł wznowić szc...
# 14    No to mam już login i hasło 😜. Wczoraj przyjęł...
# 15    Eksperci z RPA: wariant koronawirusa ten nie j...
# 16    Brytyjski minister wyraził obawy, że szczepion...
# 17    CBOS: 56 proc. Polaków chce się zaszczepić prz...
# 18    Z OSTATNIEJ CHWILI: #Szczepionka powinna sobie...
# 19    Szczepionkę #SputnikV zatwierdziło do użytku w...
# 20    W UK 200 szczepień na minutę. A Polsce jak? #S...
# 21    "nie jest do końca jasne, czy #koronawirusy ta...
# 22                                         #szczepionka
# 23    Lekarze są wściekli‼️ Tysiące lekarzy nie otrz...
# 24    Pfizer już kilkukrotnie zmieniał informacje i ...
# 25    Prokuratorzy do szczepienia przed przewlekle c...
# 26    Celebryci zaszczepieni na #WUM jako „niemedycz...
# 27    Prokuratorzy do szczepienia przed przewlekle c...
# 28    Pfizer już kilkukrotnie zmieniał informacje i ...
# 29    Ostatni dzień zapisów na szczepienia dla grupy...
# ...                                                 ...
# 6594  Wow 😮😮😮 #KORONAWIRUS #COVID19 #COVID #CovidVac...
# 6595  Brytyjski regulator MHRA dopuścił w środę 2 gr...
# 6596  Co to za dziwna rzeczywistość, gdzie w wywiadz...
# 6597  – Sceptycyzm wobec nauki to choroba cywilizacy...
# 6598  #pilne  @MZ_GOV_PL  @a_niedzielski  #szczepion...
# 6599  #Szczepionka Prezes #CureVac #JeanStephenne po...
# 6600  Po tej decyzji szczepienia mogą rozpocząć się ...
# 6601  Brytyjczycy autoryzują, jako pierwsi na świeci...
# 6602  #Pilne | Szczepionka Pfizer-BioNTech zaakcepto...
# 6603  #Szczepionka opracowana przez #Pfizer i #BioNT...
# 6604  - Kiedy pojawi się #szczepionka, wówczas natyc...
# 6605  HISZPAŃSKA FIRMA OPRACOWAŁA POJEMNIKI UTRZYMUJ...
# 6606  Leszek Kraskowski "Do Polski trafi 10 tys. szc...
# 6607  Do Polski trafi 10 tys. szczepionek przeciw gr...
# 6608  Będzie szybka decyzja KE ws. dopuszczenia szcz...
# 6609  UE: decyzja ws. dopuszczenia szczepionek Pfize...
# 6610  Jak ocenia białostocka lekarz Joanna Szeląg, n...
# 6611  Firmy @pfizer i @BioNTech_Group wystąpiły do E...
# 6612  Europejska Agencja Leków zajmuje się dopuszcza...
# 6613  @solyluna_art @slav3331 Spokojnie, wszystko je...
# 6614   https://t.co/RzhtoNDpgF Żaden ze mnie antyszc...
# 6615  Wyszły na jaw plany rządu ws. masowych szczepi...
# 6616  🇧🇬 49 proc. Bułgarów opowiada się przeciwko sz...
# 6617  Moderna wystąpiła o zezwolenie FDA i EMA na uż...
# 6618  A program zachęcania Polaków do szczepień też ...
# 6619      https://t.co/v6fweoOxyR #COVID19 #szczepionka
# 6620  Brytyjski minister ds. #szczepionka na #COVID1...
# 6621  #USA Minister zdrowia #AlexAzar zapowiedział w...
# 6622  Wiele krajów europejskich chce rozpocząć szcze...
# 6623  #Szczepionka #Moderna ogłosiła, że złoży aplik...
#
#                                        processed_tweets  oczekiwanie  \
# 0     Jakie skutki niepożądane zaobserwowano w czasi...    -0.078405
# 1     #SzczepimySię #COVID19 #Covid_19 #koronawirusp...     0.247204
# 2     (3/3)  Po wypowiedzi posła Lewicy opublikowany...     0.969343
# 3     (2/3)  O deklaracji chęci zaszczepienia na COV...     0.872439
# 4     (1/3)  Zgodnie z wynikami sondażu United Surve...     1.059799
# 5     Rozmawiają dwa szczury: - Heniu, a Ty się zasz...    -0.354499
# 6     (Jeszcze) nie zamknęli nas w obozach. #COVID19...     0.459875
# 7     Do końca pierwszego kwartału 2021 roku #BioNTe...     1.795166
# 8     Już ponad 600 tys. osób podpisało apel @Yunus_...     2.281098
# 9     Chciał bym przypomnieć że #Polacy grają z #Uru...     2.284878
# 10            #Szczepienia #szczepimysie #szczepionka       0.005137
# 11    Müller o szczepionce przeciw COVID-19   #szcze...    -0.119112
# 12    #𝐒𝐳𝐜𝐳𝐞𝐩𝐢𝐨𝐧𝐤𝐚 Pfizera NIESKUTECZNA! Teraz #USA ...     0.144957
# 13    Punkt szczepień na MTP będzie mógł wznowić szc...     0.849284
# 14    No to mam już login i hasło twarz wystawiająca...     0.864655
# 15    Eksperci z RPA: wariant koronawirusa ten nie j...    -0.755854
# 16    Brytyjski minister wyraził obawy, że szczepion...    -0.351931
# 17    CBOS: 56 proc. Polaków chce się zaszczepić prz...     0.563725
# 18    Z OSTATNIEJ CHWILI: #Szczepionka powinna sobie...     0.643025
# 19    Szczepionkę #SputnikV zatwierdziło do użytku w...     1.235450
# 20    W UK 200 szczepień na minutę. A Polsce jak? #S...     1.209710
# 21    "nie jest do końca jasne, czy #koronawirusy ta...    -0.040593
# 22                                         #szczepionka    -0.478240
# 23    Lekarze są wściekli‼️ Tysiące lekarzy nie otrz...     0.883436
# 24    Pfizer już kilkukrotnie zmieniał informacje i ...     1.354870
# 25    Prokuratorzy do szczepienia przed przewlekle c...     0.750065
# 26    Celebryci zaszczepieni na #WUM jako „niemedycz...     0.323197
# 27    Prokuratorzy do szczepienia przed przewlekle c...     0.750065
# 28    Pfizer już kilkukrotnie zmieniał informacje i ...     1.354870
# 29    Ostatni dzień zapisów na szczepienia dla grupy...     0.673531
# ...                                                 ...          ...
# 6594  Wow twarz z otwartymi ustamitwarz z otwartymi ...     2.279970
# 6595  Brytyjski regulator MHRA dopuścił w środę 2 gr...     1.615174
# 6596  Co to za dziwna rzeczywistość, gdzie w wywiadz...    -1.418866
# 6597  – Sceptycyzm wobec nauki to choroba cywilizacy...     0.596287
# 6598  #pilne  @MZ_GOV_PL  @a_niedzielski  #szczepion...     1.040507
# 6599  #Szczepionka Prezes #CureVac #JeanStephenne po...     1.295946
# 6600  Po tej decyzji szczepienia mogą rozpocząć się ...     0.790648
# 6601  Brytyjczycy autoryzują, jako pierwsi na świeci...     0.326353
# 6602  #Pilne | Szczepionka Pfizer-BioNTech zaakcepto...     1.025424
# 6603  #Szczepionka opracowana przez #Pfizer i #BioNT...    -0.058951
# 6604  - Kiedy pojawi się #szczepionka, wówczas natyc...     1.186123
# 6605  HISZPAŃSKA FIRMA OPRACOWAŁA POJEMNIKI UTRZYMUJ...    -0.150388
# 6606  Leszek Kraskowski "Do Polski trafi 10 tys. szc...    -0.126303
# 6607  Do Polski trafi 10 tys. szczepionek przeciw gr...     0.060047
# 6608  Będzie szybka decyzja KE ws. dopuszczenia szcz...     0.396924
# 6609  UE: decyzja ws. dopuszczenia szczepionek Pfize...     0.548501
# 6610  Jak ocenia białostocka lekarz Joanna Szeląg, n...     0.334560
# 6611  Firmy @pfizer i @BioNTech_Group wystąpiły do E...    -0.045521
# 6612  Europejska Agencja Leków zajmuje się dopuszcza...    -0.002579
# 6613  @solyluna_art @slav3331 Spokojnie, wszystko je...     1.778576
# 6614    Żaden ze mnie antyszczepionkowiec, ale sporo...     2.154350
# 6615  Wyszły na jaw plany rządu ws. masowych szczepi...     2.187899
# 6616  flaga: Bułgaria 49 proc. Bułgarów opowiada się...    -1.099581
# 6617  Moderna wystąpiła o zezwolenie FDA i EMA na uż...    -1.025401
# 6618  A program zachęcania Polaków do szczepień też ...     0.308071
# 6619                              #COVID19 #szczepionka    -0.464180
# 6620  Brytyjski minister ds. #szczepionka na #COVID1...     0.011149
# 6621  #USA Minister zdrowia #AlexAzar zapowiedział w...    -0.165647
# 6622  Wiele krajów europejskich chce rozpocząć szcze...     0.800211
# 6623  #Szczepionka #Moderna ogłosiła, że złoży aplik...     0.097790
#
#         podziw    radosc    smutek    strach    wstret  zaskoczenie     zlosc  \
# 0    -2.752152 -7.049420 -5.944355  3.317139 -4.097007    -3.332653 -2.177593
# 1    -4.286077 -5.076561 -2.129335  0.056217 -2.789803    -6.996193 -3.944554
# 2    -4.663278 -6.611484 -2.024936 -0.959466  2.139658    -4.985923  2.744113
# 3    -4.842559 -7.198940 -2.226286 -0.684579  2.450838    -4.415974  3.407382
# 4    -3.817860 -5.587823 -3.458345 -0.424636 -2.024174    -7.031165 -1.749990
# 5    -4.014688 -4.824597 -1.360549  1.778537 -1.828506     0.107076 -1.225100
# 6    -4.181236 -4.210942 -0.682834  0.019458 -0.865167    -3.210000 -1.002657
# 7    -1.964428 -3.483556 -4.148592 -0.535214 -4.553160    -5.494053 -2.749705
# 8     1.546575 -1.936649 -6.320982 -2.117420 -4.783503    -4.909160 -0.558561
# 9    -4.644465  0.090779  1.531593 -5.123172 -3.253448    -4.503701 -3.311231
# 10   -5.493035 -5.925822 -1.481610  0.320871 -2.728295    -7.862644 -4.820370
# 11   -5.051890 -5.719084 -1.479908  0.698610 -2.521414    -6.946292 -4.421237
# 12   -5.281740 -6.062939 -1.001400  0.407697  0.243976    -4.810007 -0.691394
# 13   -3.416914 -3.954247 -3.002743 -0.462803 -5.414680    -6.826322 -5.491457
# 14   -4.209597 -5.808838 -2.419337  0.533517 -0.411525    -1.624976  1.333776
# 6611 -4.289062 -7.307737 -3.602448  2.648930 -2.246002    -5.782153 -2.575085
# 6612 -3.748276 -7.339441 -4.687253  2.692976 -2.902583    -6.001542 -2.770631
# 6613 -3.466460 -3.349492 -1.988875 -1.509056 -3.052123    -6.050842 -2.597385
# 6614  0.333553 -0.379265 -3.848165 -2.228741 -5.034313    -2.422613 -1.527397
# 6615 -1.785510 -2.277366 -3.548805 -1.186986 -5.551164    -4.256557 -3.141312
# 6616 -4.744442 -7.546753 -2.243001  3.354285 -0.202511    -2.275007 -0.830949
# 6617 -4.438438 -8.221210 -3.823153  3.882573 -1.595234    -2.630364 -1.288025
# 6618 -2.986971 -7.373772 -5.487954  3.105762 -2.381987    -2.588666  0.179682
# 6619 -5.037351 -6.345721 -2.391356  1.471781 -3.765860    -7.372125 -5.622379
# 6620 -5.703073 -5.815416 -0.673384 -0.257465 -0.661378    -6.999794 -2.727833
# 6621 -5.348846 -7.521983 -2.581781  1.940947 -1.729175    -7.066948 -3.260234
# 6622 -4.373877 -5.019068 -2.064368 -0.159795 -3.033813    -7.321433 -4.047970
# 6623 -4.020275 -5.980061 -3.116687  1.133753 -2.613348    -6.546859 -3.380554
#
#       neutralny  neutralne
# 0      4.081343   4.081343
# 1      6.387649   6.387649
# 2      2.261405   2.261405
# 3      1.715589   1.715589
# 4      5.740261   5.740261
# 5      0.827278   0.827278
# 6      2.639622   2.639622
# 7      4.583469   4.583469
# 8      1.725296   1.725296
# 9      2.330388   2.330388
# 10     7.300437   7.300437
# 11     6.621212   6.621212
# 12     3.711533   3.711533
# 13     6.555061   6.555061
# 14     1.038876   1.038876
# 15     5.836118   5.836118
# 16     4.792735   4.792735
# 17     6.154382   6.154382
# 18     4.523548   4.523548
# 19     5.403351   5.403351
# 20     2.536822   2.536822
# 21     5.018247   5.018247
# 22     7.583141   7.583141
# 23     1.928407   1.928407
# 24     4.598131   4.598131
# 25     5.070356   5.070356
# 26     3.472856   3.472856
# 27     5.070356   5.070356
# 28     4.598131   4.598131
# 29     6.918436   6.918436
# ...         ...        ...
# 6594   1.793253   1.793253
# 6595   3.302248   3.302248
# 6596   0.202916   0.202916
# 6597   5.476471   5.476471
# 6598   3.731109   3.731109
# 6599   6.915481   6.915481
# 6600   6.224860   6.224860
# 6601   4.168936   4.168936
# 6602   5.011672   5.011672
# 6603   6.376707   6.376707
# 6604   5.782404   5.782404
# 6605   5.063287   5.063287
# 6606   6.545942   6.545942
# 6607   6.498779   6.498779
# 6608   6.887601   6.887601
# 6609   6.805484   6.805484
# 6610   5.838040   5.838040
# 6611   5.630636   5.630636
# 6612   5.823053   5.823053
# 6613   4.692847   4.692847
# 6614   1.006983   1.006983
# 6615   3.827117   3.827117
# 6616   2.485383   2.485383
# 6617   3.338803   3.338803
# 6618   2.599811   2.599811
# 6619   7.507052   7.507052
# 6620   5.750368   5.750368
# 6621   6.699419   6.699419
# 6622   6.414879   6.414879
# 6623   5.994273   5.994273
#
# [6624 rows x 14 columns]
